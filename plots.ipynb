# %%
# %matplotlib inline
import matplotlib.pyplot as plt
x = [1,2,3,4,5]
y = [300,500,20,150,500]
plt.plot(x,y,'b--', c='g')
plt.xlabel('numbers')
plt.ylabel('more numbers')
# Out:
# Text(0,0.5,'more numbers')
